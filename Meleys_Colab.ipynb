# %% [markdown]
# # Meleys Colab\n\nStartovni notebook pro praci s projektem Meleys v Google Colabu.

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# !git clone https://github.com/HelenaVotavova/Meleys.git /content/Meleys || true\n%cd /content/Meleys\n!git pull

# %%
import sys, platform\nprint('Python:', sys.version)\nprint('Platform:', platform.platform())\nprint('Notebook pripraven.')
